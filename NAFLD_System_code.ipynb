# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score

# Load dataset
df = pd.read_csv(r'C:\Users\adity\OneDrive\Documents\project\NAFLD\resampled_ILPD.csv')

# Check for the 'gender' column
if 'gender' in df.columns:
    # Encode 'Gender' column if it exists
    label_encoder = LabelEncoder()
    df['gender'] = label_encoder.fit_transform(df['gender'])

# Ensure the target variable has only 0 and 1
df['is_patient'] = df['is_patient'].map({1: 0, 2: 1})

# Handle missing values
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Assign weights based on the new analysis
weights = {
    'direct_bilirubin': -1.0,  # High negative weight
    'tot_bilirubin': -1.0,     # High negative weight
    'tot_proteins': 1.0,       # High positive weight
    'albumin': -1.0,           # High negative weight
    'ag_ratio': 0.5,           # Moderate positive weight
    'sgpt': 1.0,               # High positive weight
    'sgot': 1.0,               # High positive weight
    'alkphos': 1.0             # High positive weight
}

# Apply weights to the features
for feature, weight in weights.items():
    df_imputed[feature] *= weight

# Preprocessing
scaler = MinMaxScaler()
X = scaler.fit_transform(df_imputed.iloc[:, :-1].values)
y = df_imputed.iloc[:, -1].values

# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# Define models
models = {
    'XGB': XGBClassifier(),
    'Support Vector Machine': SVC(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'kNN': KNeighborsClassifier(),
    'SGD': SGDClassifier(),
}

# Define hyperparameter grids
param_grids = {
    'XGB': {
        'n_estimators': [100, 200, 500],
        'max_depth': [3, 6, 10],
        'learning_rate': [0.01, 0.1, 0.2]
    },
    'Support Vector Machine': {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf', 'sigmoid'],
        'gamma': ['scale', 'auto']
    },
    'Decision Tree': {
        'max_depth': [10, 20, 50, 100],
        'min_samples_split': [2, 5, 10]
    },
    'Random Forest': {
        'n_estimators': [100, 200, 500],
        'max_depth': [10, 20, 50, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'kNN': {
        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    },
    'SGD': {
        'loss': ['hinge', 'log', 'modified_huber'],
        'penalty': ['l2', 'l1', 'elasticnet'],
        'alpha': [0.0001, 0.001, 0.01]
    }
}

# Function for tuning models with Grid Search
def tune_model_grid_search(model, param_grid):
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
    grid_search.fit(x_train, y_train)
    best_model = grid_search.best_estimator_
    print("Best parameters for {}: {}".format(type(model).__name__, grid_search.best_params_))
    return best_model

# Function for tuning models with Random Search
def tune_model_random_search(model, param_grid):
    random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=100, cv=5, scoring='accuracy', verbose=2, n_jobs=-1, random_state=42)
    random_search.fit(x_train, y_train)
    best_model = random_search.best_estimator_
    print("Best parameters for {}: {}".format(type(model).__name__, random_search.best_params_))
    return best_model

# Fine-tune models using Grid Search and Random Search
best_models = {}
for model_name in models:
    print(f"Tuning {model_name} with Grid Search...")
    best_models[f"{model_name}_grid_search"] = tune_model_grid_search(models[model_name], param_grids[model_name])
    print(f"Tuning {model_name} with Random Search...")
    best_models[f"{model_name}_random_search"] = tune_model_random_search(models[model_name], param_grids[model_name])

# Evaluate models
print("Test Set Prediction:\n")
for model_name, model in best_models.items():
    print('-' * 20 + model_name + '-' * 20)
    y_pred = model.predict(x_test)
    print(classification_report(y_test, y_pred, digits=5))
    cf_matrix = confusion_matrix(y_test, y_pred)
    ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values ')
    ax.xaxis.set_ticklabels(['False', 'True'])
    ax.yaxis.set_ticklabels(['False', 'True'])
    plt.show()
# Out:
# Tuning XGB with Grid Search...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters for XGBClassifier: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# Tuning XGB with Random Search...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\adity\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 27 is smaller than n_iter=100. Running 27 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best parameters for XGBClassifier: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.01}
# Tuning Support Vector Machine with Grid Search...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best parameters for SVC: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Tuning Support Vector Machine with Random Search...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# c:\Users\adity\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 18 is smaller than n_iter=100. Running 18 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# c:\Users\adity\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 12 is smaller than n_iter=100. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best parameters for SVC: {'kernel': 'rbf', 'gamma': 'scale', 'C': 10}
# Tuning Decision Tree with Grid Search...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters for DecisionTreeClassifier: {'max_depth': 10, 'min_samples_split': 5}
# Tuning Decision Tree with Random Search...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best parameters for DecisionTreeClassifier: {'min_samples_split': 2, 'max_depth': 20}
# Tuning Random Forest with Grid Search...
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best parameters for RandomForestClassifier: {'max_depth': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Tuning Random Forest with Random Search...
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Best parameters for RandomForestClassifier: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 20}
# Tuning kNN with Grid Search...
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best parameters for KNeighborsClassifier: {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'distance'}
# Tuning kNN with Random Search...
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# c:\Users\adity\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 32 is smaller than n_iter=100. Running 32 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best parameters for KNeighborsClassifier: {'weights': 'distance', 'n_neighbors': 9, 'algorithm': 'auto'}
# Tuning SGD with Grid Search...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters for SGDClassifier: {'alpha': 0.001, 'loss': 'hinge', 'penalty': 'l1'}
# Tuning SGD with Random Search...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best parameters for SGDClassifier: {'penalty': 'l1', 'loss': 'modified_huber', 'alpha': 0.001}
# Test Set Prediction:
#
# --------------------XGB_grid_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.95238   0.90909   0.93023        22
#          1.0    0.91304   0.95455   0.93333        22
#
#     accuracy                        0.93182        44
#    macro avg    0.93271   0.93182   0.93178        44
# weighted avg    0.93271   0.93182   0.93178        44
# c:\Users\adity\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 27 is smaller than n_iter=100. Running 27 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# --------------------XGB_random_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.95238   0.90909   0.93023        22
#          1.0    0.91304   0.95455   0.93333        22
#
#     accuracy                        0.93182        44
#    macro avg    0.93271   0.93182   0.93178        44
# weighted avg    0.93271   0.93182   0.93178        44
# --------------------Support Vector Machine_grid_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.88889   0.72727   0.80000        22
#          1.0    0.76923   0.90909   0.83333        22
#
#     accuracy                        0.81818        44
#    macro avg    0.82906   0.81818   0.81667        44
# weighted avg    0.82906   0.81818   0.81667        44
# --------------------Support Vector Machine_random_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.88889   0.72727   0.80000        22
#          1.0    0.76923   0.90909   0.83333        22
#
#     accuracy                        0.81818        44
#    macro avg    0.82906   0.81818   0.81667        44
# weighted avg    0.82906   0.81818   0.81667        44
# --------------------Decision Tree_grid_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.85000   0.77273   0.80952        22
#          1.0    0.79167   0.86364   0.82609        22
#
#     accuracy                        0.81818        44
#    macro avg    0.82083   0.81818   0.81781        44
# weighted avg    0.82083   0.81818   0.81781        44
# --------------------Decision Tree_random_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.85000   0.77273   0.80952        22
#          1.0    0.79167   0.86364   0.82609        22
#
#     accuracy                        0.81818        44
#    macro avg    0.82083   0.81818   0.81781        44
# weighted avg    0.82083   0.81818   0.81781        44
# --------------------Random Forest_grid_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    1.00000   0.77273   0.87179        22
#          1.0    0.81481   1.00000   0.89796        22
#
#     accuracy                        0.88636        44
#    macro avg    0.90741   0.88636   0.88488        44
# weighted avg    0.90741   0.88636   0.88488        44
# --------------------Random Forest_random_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    1.00000   0.81818   0.90000        22
#          1.0    0.84615   1.00000   0.91667        22
#
#     accuracy                        0.90909        44
#    macro avg    0.92308   0.90909   0.90833        44
# weighted avg    0.92308   0.90909   0.90833        44
# --------------------kNN_grid_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.72222   0.59091   0.65000        22
#          1.0    0.65385   0.77273   0.70833        22
#
#     accuracy                        0.68182        44
#    macro avg    0.68803   0.68182   0.67917        44
# weighted avg    0.68803   0.68182   0.67917        44
# --------------------kNN_random_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.72222   0.59091   0.65000        22
#          1.0    0.65385   0.77273   0.70833        22
#
#     accuracy                        0.68182        44
#    macro avg    0.68803   0.68182   0.67917        44
# weighted avg    0.68803   0.68182   0.67917        44
# --------------------SGD_grid_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.92308   0.54545   0.68571        22
#          1.0    0.67742   0.95455   0.79245        22
#
#     accuracy                        0.75000        44
#    macro avg    0.80025   0.75000   0.73908        44
# weighted avg    0.80025   0.75000   0.73908        44
# --------------------SGD_random_search--------------------
#               precision    recall  f1-score   support
#
#          0.0    0.93750   0.68182   0.78947        22
#          1.0    0.75000   0.95455   0.84000        22
#
#     accuracy                        0.81818        44
#    macro avg    0.84375   0.81818   0.81474        44
# weighted avg    0.84375   0.81818   0.81474        44

# %%
# Feature importance for XGBClassifier
xgb_model = best_models['XGB_grid_search']
xgb_importance = xgb_model.feature_importances_

# Feature importance for Random Forest
rf_model = best_models['Random Forest_grid_search']
rf_importance = rf_model.feature_importances_

# Plotting feature importance
features = df_imputed.columns[:-1]
xgb_importance_df = pd.DataFrame({'Feature': features, 'Importance': xgb_importance}).sort_values(by='Importance', ascending=False)
rf_importance_df = pd.DataFrame({'Feature': features, 'Importance': rf_importance}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x='Importance', y='Feature', data=xgb_importance_df)
plt.title('XGBClassifier Feature Importance')

plt.subplot(1, 2, 2)
sns.barplot(x='Importance', y='Feature', data=rf_importance_df)
plt.title('Random Forest Feature Importance')

plt.tight_layout()
plt.show()
